# %% [markdown]
# #### Legende
# > Theorie, en eventueel **nieuwe begrippen**. </br>
#
# ℹ️ Informatief. Geen leerstof.</br>
# ⚛️ Meer diepgaande stof. Best eens lezen maar niet vanbuiten leren. </br>
# 🆘 Tips bij het programmeren. Veelgemaakte fouten.</br>
# ✳️ Enkel leerstof voor bepaalde klassen.

# %% [markdown]
# # H2.1 Bewerkingen</h1>

# %% [markdown]
# ## 1. Bewerkingen met getallen</h2>

# %% [markdown]
# Python kan worden gebruikt om eenvoudige rekensommen op te bouwen aan de hand van onder anderen de volgende operatoren.
#
# > `+`  <t>Optelling<br>
# > `-`  <t>Aftrekking<br>
# > `*`  <t>Vermenigvuldiging<br>
# > `/`  <t>Deling<br>
# > `**` <t>Machtsverheffing<br>

# %% [markdown]
# #### Voorbeeld

# %%
10+4

# %%
10-4

# %%
10*4

# %%
10/4

# %%
10**4

# %% [markdown]
# Wanneer we meer geavanceerde formules willen opbouwen geldt de volgorde van bewerkingen zoals in de wiskunde. Je kan hierbij gebruik maken van haakjes.

# %% [markdown]
# #### Voorbeeld

# %%
(18+6)/3

# %%
18+6/3

# %% [markdown]
# Naast de "echte" deling kan je ook deling met rest toepassen.
#
# > `//` Quotiënt (geheel getal)<br>
# > `%` Rest

# %% [markdown]
# #### Voorbeeld

# %%
45//7

# %%
45%7

# %% [markdown]
# ## 2. Bewerkingen met tekst</h2>

# %% [markdown]
# Enkele van bovenstaande bewerkingen zijn ook voor strings gedefiniëerd:
#
# > `+`  <t>Concatenatie (samenvoeging)<br>
# > `*`  <t>Herhaling<br>

# %% [markdown]
# #### Voorbeeld

# %%
"Dit is een eerste tekst" + " en dit is een tweede tekst" + "!"

# %%
3*"Herhaal dit drie keer! "

# %% [markdown]
# >  Sommige karakters hebben een speciale betekenis. Om dit aan te duiden gebruiken we het *escape karakter* `\`. <br>
# `\'`	Enkele quote (`'`)<br>
# `\"`	Dubbele quote (`"`)<br>
# `\n`	Nieuwe lijn<br>
# `\t`	Nieuwe tab<br>
# `\\`	Backslash (`\`)<br>

# %% [markdown]
# #### Voorbeeld

# %%
print("\"Ernie, er zit een banaan in je oor\" \n zij Bert.")

# %% [markdown]
# ## 3. Variabelen

# %% [markdown]
# > Een **variabele** is een tijdelijke plaats in het geheugen waarin een object (bijvoorbeeld een getal of tekst) kan worden bijgehouden.
# > Wanneer we werken met variabelen beschouwen we twee operaties: Een **toekenning** en een **oproep**.
# - Een nieuwe variabele wordt automatisch gecreërd wanneer we de eerste keer object toekennen. We gebuiken hierbij de `=`-operator. Je geeft de variabele dan een duidelijke en zinvolle naam.
# - Door de naam van de variabele in je code te verwerken kan je het object dat in de variabele zit opgeslagen oproepen.

# %% [markdown]
# #### Voorbeelden

# %% [markdown]
# In onderstaand voorbeeld creëren we een variabele met als naam `getal` en kennen we als object de waarde `8` toe.

# %%
getal = 8

# %% [markdown]
# ![9iR5LrypT.png](data:image/png;base64,...)

# %% [markdown]
# Je kan dan verderop in je code de variabele oproepen. Je gebruikt dan de waarde die in de variabele is opgeslagen.

# %%
getal = 8
print("Het getal x is gelijk aan", getal)

# %% [markdown]
# Je kan de waarde die in een variabele zit ook gebruiken in de toekenning van een andere variabele.

# %%
getal = 8
getal_plus_twee = getal + 2
print("Twee meer dan", getal, "is", getal_plus_twee)

# %% [markdown]
# Je kan ook het resultaat van een operatie op een variabele terug in dezelfde variabele opslaan.

# %%
getal = 8
getal = getal + 2
print("Twee meer is", getal)

# %% [markdown]
# Dit kan echter nog eenvoudiger met samengestelde operatoren.

# %% [markdown]
# > Via **samengestelde opereratoren** kan je voor een variabele een operatie op zichzelf definiëren: `+=`, `-=`, `*=`, `/=`,... <br>
# Zo is bijvoorbeeld `x -= 3` equivalent aan `x = x - 3`.

# %% [markdown]
# #### Voorbeeld

# %%
getal = 7
getal += 2
print("Twee meer is", getal)

# %% [markdown]
# #### Oefening 1

# %% [markdown]
# Schrijf code die aan twee variabelen een waarde toekent en het product op het scherm print.

# %% [markdown]
# #### Opmerkingen ⚛

# %% [markdown]
# Kies steeds duidelijke namen voor je variabelen. Let hierbij op het volgende:
# - Namen van variabelen zijn hoofdlettergevoelig.
#   - Dus `getal` en `Getal` verwijzen naar 2 verschillende variabelen.
# - Cijfers aan het begin van een variabelenaam, spaties en het `-` symbool zijn niet toegelaten. Dus bijvoorbeeld niet:
#   - `1MijnVariabele`
#   - `Mijn Variabele`
#   - `Mijn-Variabele`
# - Enkele sleutelwoorden zijn in Python gereserveerd voor andere doeleinden en kunnen dus ook niet worden gebruikt als variabelenaam:
# ```
# and       del       from      None      True
# as        elif      global    nonlocal  try
# assert    else      if        not       while
# break     except    import    or        with
# class     False     in        pass      yield
# continue  finally   is        raise
# def       for       lambda    return
# ```

# %% [markdown]
# 🆘 Een veelgemaakte fout is een variabele oproependat voor ze een waarde heeft toegekent gekregen.

# %% [markdown]
# #### Oefening 2

# %% [markdown]
# Onderstaande code roept de variabele `getal` zonder een voorafgaande toekenning. Wat gebeurt er als je deze code laat lopen? Hoe kan je dit oplossen?

# %%
print("De waarde van het getal is ", ingevoerd_getal)

# %% [markdown]
# ## 4. Datatypes

# %% [markdown]
# In de vorige paragraaf werd een variabele beschereven als een stuk geheugen dat een stuk data in de vorm van een object bijhoud. Zo'n object kan verschillende vormen aannemen.
#
# > Een **datatype** beschrijft wat voor soort informatie een object voorstelt.
#
# ℹ In Python zijn 15 verschillende datatypes gedefiniëerd:
# `str, int, float, complex, list, tuple, range, dict, set, frozenset, bool, bytes, bytearray, memoryview, NoneType`
#
# > We behandelen hier drie soorten datatypes:
# > - `str` = Een **string** = Een reeks symbolen die een text kunnen vormen
# >   - Bijvoorbeeld: `"Dit is een tekst"`, `"Hello world!"`, `"!"`,...
# > - `int` = Een **integer** = Een geheel getal
# >   - Bijvoorbeeld: `"1000000"`, `"12"`, `"-396"`,...
# > - `float` = Een **floating point number** = Een reëel getal
# >   - In Python worden kommagetallen met een `.`aangeduid.
# >     - Bijvoorbeeld: `-14.52`, `.1263`, `-200.0`,...
# >   - Onderstaande voorbeelden duiden de wetenschappelijke notatie aan.
# >     - Bijvoorbeeld: `-21.13e12` = -21,13·10¹²

# %% [markdown]
# ![Basic-Data-Types-in-Python_Watermarked copy.png](data:image/png;base64,...)

# %% [markdown]
# > Via de functie `type()` kan je het datatype van een object checken.

# %% [markdown]
# #### Voorbeeld

# %%
a = "Dit is een tekst"
b = -75
c = 12.9

print(type(a))
print(type(b))
print(type(c))

# %% [markdown]
# **[⚛]** In andere programmeertalen moet vaak bij het aanmaken van een variabele een datatype worden meegegeven. In Python gebeurt dit automatisch. De interpreter kiest zelf het datatype van een object aan de hand van zijn kenmerken. Dit concept wordt ook wel **duck typing** genoemd.

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### Voorbeeld

# %% [markdown]
# Tweemaal hetzelfde getal, maar met een andere notatie, levert twee verschillende datatypes.

# %%
a = -94
b = -94.

print(type(a))
print(type(b))

# %% [markdown]
# ⚛ Bovendien kan het datatype van een object veranderen. Dit heet **dynamic typing**.

# %% [markdown]
# #### Voorbeeld

# %% [markdown]
# Door een `int` met een `1.2` te vermenigvuldigen krijgen we een `float`.

# %%
a = 10
print(type(a))

a *= 1.2
print(type(a))

# %% [markdown]
# Afhankelijk van het datatype van een object kunnen bewerkingen een verschillend effect hebben.

# %% [markdown]
# #### Oefening 3

# %% [markdown]
# Gegeven onderstaande code die twee variabelen aanmaakt. Vermenigvuldig beide variabelen met 2 en print het resultaat op het scherm. Wat is het verschil?

# %%
a = '3'
b = 3
# Code hier

# %% [markdown]
# Wil je toch een datatype zelf aan een object toekennen? Gebruik dan de functies `int()`, `float()` en `str()`.

# %% [markdown]
# #### Voorbeeld

# %%
a = 13
b = float(13)

print(type(a))
print(type(b))

# %% [markdown]
# #### Oefening 4

# %% [markdown]
# Gegeven dezelfde starterscode als de vorige oefening. Zorg er nu voor dat het de vermenigvuldiging met 2 bij beide variabelen hetzelfde resultaat oplevert.

# %%
a = '3'
b = 3
# Code hier

# %% [markdown]
# #### Oefening 5

# %% [markdown]
# Herschrijf je code van oefening 1. Maar vraag deze keer aan de gebruiker 2 getallen om te vermenigvuldigen.
#
# Tip: Check eerst eens het datatype van de invoer.

# %% [markdown]
# ## 5. Modules

# %% [markdown]
# Uiteraard kan maar een beperkte functionaliteit aan een programmeertaal worden toegevoegd. Merk bijvoorbeeld op dat in Python een bewerking ontbreekt om de worteltrekking uit te voeren. Hiervoor doet men beroep op modules.
#
# > Een **module** is een bibliotheek van extra functionaliteit die aan een programma kan worden toegevoegd. Je moet vooraf aangeven wanneer je een bepaalde module aan je programma wil toevoegen. Dit kan met het `import` sleutelwoord.

# %% [markdown]
# #### Voorbeeld

# %% [markdown]
# Om de worteltrekking in Python toe te passen importeren we de module `math`. Deze module bevat allerlei extra wiskundige bewerkingen: https://docs.python.org/3/library/math.html
#
# In de documentatie lezen we dat we de worteltrekking kunnen uitvoeren via de `sqrt()` functie.

# %%
import math       # Module importeren

x = 49
wortel = math.sqrt(x)
print("De vierkantswortel van", x, "is", wortel)

# %% [markdown]
# Merk op dat we steeds het de naam van de module als voorvoegsel aan de functie `sqrt` moeten toevoegen om te specifiëren dat deze uit de `math` module komt.
#
# We kunnen dit ook vergemakkelijken door een nieuwe (kortere) naam voor de module door te voeren.

# %%
import math as m      # Module importeren en een nieuwe naam geven

x = 49
wortel = m.sqrt(x)
print("De vierkantswortel van", x, "is", wortel)

# %% [markdown]
# Als we, zoals in dit geval, maar één functie uit de module gebruiken hoeven we ook niet heel de module in te laden. Je kan bij het importeren aangeven welke functies je nodig hebt.

# %%
from math import sqrt       # Importeer enkel sqrt uit de module math

x = 49
wortel = sqrt(x)      # De module nog eens specifieren is nu niet langer nodig
print("De vierkantswortel van", x, "is", wortel)

# %% [markdown]
# #### Oefening 6

# %% [markdown]
# Schrijf code die aan de gebruiken een getal vraagt en de sinus van dat getal teruggeeft. Gebruik de `math` module. Tip: Kijk eens in de documentatie.

# %% [markdown]
# </br></br>
#
# ℹ Er bestaan meer dan 400 000 modules voor Python. De ene is al wat nuttiger dan de andere. Hieronder een paar zinloze, maar wel interessante Python modules.

# %% [markdown]
# **Pyperclip** laat je de functies copy en paste in Python toepassen: https://pypi.org/project/pyperclip/

# %% [markdown]
# **Turtle** laat je op het scherm tekenen: https://docs.python.org/3/library/turtle.html

# %% [markdown]
# Met **Pygame** kan je zelf eenvoudige games programmeren: https://www.pygame.org/news

# %% [markdown]
# Met **Emoji** kan je emoji's op het scherm printen: https://www.geeksforgeeks.org/10-interesting-modules-in-python-to-play-with/

# %%
# !pip3 install emoji > /dev/null # Extra commando om module te installeren

import emoji
print(emoji.emojize('Python is :thumbs_up:'))

# %% [markdown]
# Met **Wikipedia** kan je Python volledige Wikipediapagina's laten opzoeken en printen: https://pypi.org/project/wikipedia/

# %%
# !pip3 install wikipedia > /dev/null # Extra commando om module te installeren

import wikipedia
print(wikipedia.summary("Python (programming language)"))

# %% [markdown]
# Met **Colorama** kan je tekt in een kleurtje uitvoeren: https://pypi.org/project/colorama/

# %%
# !pip3 install colorama > /dev/null # Extra commando om module te installeren

import colorama
print(colorama.Fore.RED + 'Some red text ' + colorama.Back.YELLOW + 'with a yellow background')

# %% [markdown]
# En **Cowsay** moet je zelf maar eens uitproberen.

# %%
# !pip3 install cowsay > /dev/null # Extra commando om module te installeren

import cowsay
cowsay.cow("Beu")
